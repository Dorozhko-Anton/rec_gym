# %%
import pandas as pd
import numpy as np

# %%
# !ls /home/anton/.surprise_data/ml-100k/
# Out:
# allbut.pl  README   u2.base  u3.test  u5.base  ua.test	u.data	 u.item
# mku.sh	   u1.base  u2.test  u4.base  u5.test  ub.base	u.genre  u.occupation
# ml-100k    u1.test  u3.base  u4.test  ua.base  ub.test	u.info	 u.user

# %%
pd.read_csv('/home/anton/.surprise_data/ml-100k/u.data', sep='\t', 
            names=['user', 'item', 'rank', 'timestamp'])
# Out:
#        user  item  rank  timestamp
# 0       196   242     3  881250949
# 1       186   302     3  891717742
# 2        22   377     1  878887116
# 3       244    51     2  880606923
# 4       166   346     1  886397596
# 5       298   474     4  884182806
# 6       115   265     2  881171488
# 7       253   465     5  891628467
# 8       305   451     3  886324817
# 9         6    86     3  883603013
# 10       62   257     2  879372434
# 11      286  1014     5  879781125
# 12      200   222     5  876042340
# 13      210    40     3  891035994
# 14      224    29     3  888104457
# 15      303   785     3  879485318
# 16      122   387     5  879270459
# 17      194   274     2  879539794
# 18      291  1042     4  874834944
# 19      234  1184     2  892079237
# 20      119   392     4  886176814
# 21      167   486     4  892738452
# 22      299   144     4  877881320
# 23      291   118     2  874833878
# 24      308     1     4  887736532
# 25       95   546     2  879196566
# ...

# %% [markdown]
# # Create some embeddings (NMF)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def create_memory(sessions, K):
    memory = []
    
    for i, session in enumerate(sessions):
        
        L = len(session)
        for l in range(1, L, K):
            # observe state
            s = 
            # observe action
            a = 
            # observe reward
            r = 
            # add to M
            
            for k in range(K):
                if r[k] > 0:
                    s.pop(0)
                    s.append(a[k])
    
    return memory
